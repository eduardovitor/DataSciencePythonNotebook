# %% [markdown]
# Meu resumo sobre o que pode ser feito com a biblioteca Matplotlib

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# Gráfico de linha com Matplotlib

# %%
x = [1,2]
y = [3,4]

plt.plot(x,y)
plt.show()

# %% [markdown]
# Colocando legenda no gráfico

# %%
x = [1,2,5]
y = [2,3,7]

# Título
plt.title("Meu primeiro gráfico com Python")

# Legendas nos eixos

plt.xlabel("Eixo X")
plt.ylabel("Eixo Y")

plt.plot(x,y)
plt.show()

# %% [markdown]
# Gráfico de barras

# %%
x = [1,2,3,4,5]
y = [2,3,7,1,0]

titulo="Gráfico de barras"
eixox="Eixo X"
eixoy="Eixo Y"
# Título
plt.title(titulo)

# Legendas nos eixos

plt.xlabel(eixox)
plt.ylabel(eixoy)

plt.bar(x,y)
plt.show()

# %% [markdown]
# Comparando dois gráficos de barra

# %%
x1 = [1,3,5,7,9]
y1 = [2,3,7,1,0]

x2 = [2,4,6,8,10]
y2 = [5,1,3,7,4]

titulo="Gráfico de barras 2"
eixox="Eixo X"
eixoy="Eixo Y"
# Título
plt.title(titulo)

# Legendas nos eixos

plt.xlabel(eixox)
plt.ylabel(eixoy)

plt.bar(x1,y1, label="Grupo 1")
plt.bar(x2,y2, label= "Grupo 2")
# Plotando legenda dos grupos
plt.legend()
plt.show()

# %% [markdown]
# Plotando o scatterplot

# %%
x = [1,3,5,7,9]
y = [2,3,7,1,0]

titulo="Scatterplot"
eixox="Eixo X"
eixoy="Eixo Y"
# Título
plt.title(titulo)
# Legendas nos eixos
plt.xlabel(eixox)
plt.ylabel(eixoy)

plt.scatter(x,y)

plt.show()

# %% [markdown]
# Plotando scatterplot + gráfico de linhas

# %%
x = [1,3,5,7,9]
y = [2,3,7,1,0]

titulo="Scatterplot"
eixox="Eixo X"
eixoy="Eixo Y"
# Título
plt.title(titulo)
# Legendas nos eixos
plt.xlabel(eixox)
plt.ylabel(eixoy)

plt.scatter(x,y)
plt.plot(x,y)
plt.show()

# %% [markdown]
# Usando marcadores, cores e tamanhos diferentes nos gráficos

# %%
x = [1,3,5,7,9]
y = [2,3,7,1,0]

titulo="Scatterplot"
eixox="Eixo X"
eixoy="Eixo Y"
# Título
plt.title(titulo)
# Legendas nos eixos
plt.xlabel(eixox)
plt.ylabel(eixoy)
 # color=cor ; marker=símbolo usado no gráfico (geralmente é ponto) ; s=tamanho do marcador ; linestyle=estilo da linha
plt.scatter(x,y, label="Meus pontos", color="g", marker="h", s=100)
plt.plot(x,y, linestyle=":")
plt.legend()
plt.show()

# %% [markdown]
# Salvando figuras

# %%
x = [1,3,5,7,9]
y = [2,3,7,1,0]

titulo="Scatterplot"
eixox="Eixo X"
eixoy="Eixo Y"
# Título
plt.title(titulo)
# Legendas nos eixos
plt.xlabel(eixox)
plt.ylabel(eixoy)
 # color=cor ; marker=símbolo usado no gráfico (geralmente é ponto) ; s=tamanho do marcador ; linestyle=estilo da linha
plt.scatter(x,y, label="Meus pontos", color="g", marker="h", s=100)
plt.plot(x,y, linestyle=":")
plt.legend()
plt.show()

plt.savefig("figura.pdf") # Salvando em pdf
plt.savefif("figura.png", dpi=300) # Salvando em png com qualidade boa (300 dpi)

# %% [markdown]
# Estudo de caso Crescimento da População da Brasileira

# %% [markdown]
# Lendo os dados sem libs

# %%
dados = open("populacao_brasileira.csv").readlines()

x_anos=[]
y_pop=[]

for i in range(len(dados)):
  if i != 0:
    linha=dados[i].split(";")
    x_anos.append(int(linha[0]))
    y_pop.append(int(linha[1]))

# %% [markdown]
# Plotando os dados

# %%
plt.plot(x_anos,y_pop)
plt.title("Crescimento da população brasileira 1980-2016")
plt.xlabel("Anos")
plt.ylabel("População x 100 000 000")
plt.show()

# %% [markdown]
# Melhorando a visualização

# %%
plt.bar(x_anos,y_pop, color="grey")
plt.plot(x_anos,y_pop)
plt.title("Crescimento da população brasileira 1980-2016")
plt.xlabel("Anos")
plt.ylabel("População x 100 000 000")
plt.show()

# %% [markdown]
# Criando boxplots

# %%
import random

vetor = []

for i in range(0,100):
    numero_aleatorio=random.randint(0,50)
    vetor.append(numero_aleatorio)

plt.boxplot(vetor)
plt.title("Boxplot de teste")
plt.show()
